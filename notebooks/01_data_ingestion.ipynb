# %%
from src.ingestion.sentinel_loader import fetch_sentinel_data
from src.utils.config import Config

items = fetch_sentinel_data(Config.BBOX, Config.DATE_RANGE)

print("Total images:", len(items))
